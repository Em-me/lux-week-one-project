# %%
import pandas as pd
import numpy as np

# %%
data_2020 = pd.read_csv('IT Salary Survey EU  2020.csv')
data_2019 = pd.read_csv('T Salary Survey EU 2019.csv')
data_2018 = pd.read_csv('IT Salary Survey EU 2018.csv')

# %%
data_2020.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
data_2020.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
data_2020.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
import seaborn as sns
sns.histplot(data_2020['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data_2020['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
data_2020['City'].value_counts()
# Out:
# Berlin         681
# Munich         236
# Frankfurt       44
# Hamburg         40
# Stuttgart       26
#               ...
# Nuremberg        1
# Lübeck           1
# Malta            1
# Dresden          1
# Saarbrücken      1
# Name: City, Length: 119, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(22,8))
sns.histplot(data_2020['Seniority level'])
# Out:
# <AxesSubplot:xlabel='Seniority level', ylabel='Count'>

# %%
data_2020['Number of vacation days'].value_counts()
# Out:
# 30                                              488
# 28                                              233
# 27                                              102
# 25                                               91
# 26                                               71
# 24                                               67
# 29                                               24
# 20                                               13
# 21                                               10
# 32                                                8
# 31                                                8
# 22                                                8
# 36                                                5
# 35                                                5
# 40                                                4
# 0                                                 4
# 23                                                4
# 45                                                3
# ...

# %%
plt.figure(figsize=(14,10))
sns.histplot(data_2020['Main language at work'])
# Out:
# <AxesSubplot:xlabel='Main language at work', ylabel='Count'>
